# %%
import requests
import pandas as pd

# %%
# Define the API endpoint for the specified indicator
indicator_code = "SA_0000001444"
url = f"https://ghoapi.azureedge.net/api/{indicator_code}"

# %%
# Send a GET request to the API
response = requests.get(url)

# %%
# Check if the request was successful
if response.status_code == 200:
    data = response.json()
    print("Data fetched successfully!")
else:
    print(f"Failed to fetch data. Status code: {response.status_code}")
    exit()
# Out:
# Data fetched successfully!

# %%
# Normalize the JSON data into a pandas DataFrame
df = pd.json_normalize(data['value'])

# Display the first few rows of the DataFrame
print(df.head())
# Out:
#         Id  IndicatorCode SpatialDimType SpatialDim ParentLocationCode  \
# 0  4005777  SA_0000001444        COUNTRY        EST                EUR
# 1     5547  SA_0000001444        COUNTRY        IND               SEAR
# 2  2081574  SA_0000001444        COUNTRY        FJI                WPR
# 3   465140  SA_0000001444        COUNTRY        MUS                AFR
# 4  3169152  SA_0000001444        COUNTRY        CZE                EUR
#
#   TimeDimType   ParentLocation Dim1Type  TimeDim      Dim1  ... DataSourceDim  \
# 0        YEAR           Europe      SEX     2004   SEX_MLE  ...          None
# 1        YEAR  South-East Asia      SEX     2004   SEX_MLE  ...          None
# 2        YEAR  Western Pacific      SEX     2004  SEX_FMLE  ...          None
# 3        YEAR           Africa      SEX     2004  SEX_BTSX  ...          None
# 4        YEAR           Europe      SEX     2004  SEX_BTSX  ...          None
#
#    Value NumericValue   Low  High Comments                       Date  \
# 0  326.7        326.7  None  None     None  2013-06-11T14:15:34+02:00
# 1  239.3        239.3  None  None     None  2013-06-11T14:15:34+02:00
# 2   71.9         71.9  None  None     None  2013-06-11T14:15:34+02:00
# 3  225.1        225.1  None  None     None  2013-06-11T14:15:34+02:00
# 4  148.0        148.0  None  None     None  2013-06-11T14:15:34+02:00
#
#    TimeDimensionValue         TimeDimensionBegin           TimeDimensionEnd
# 0                2004  2004-01-01T00:00:00+01:00  2004-12-31T00:00:00+01:00
# 1                2004  2004-01-01T00:00:00+01:00  2004-12-31T00:00:00+01:00
# 2                2004  2004-01-01T00:00:00+01:00  2004-12-31T00:00:00+01:00
# 3                2004  2004-01-01T00:00:00+01:00  2004-12-31T00:00:00+01:00
# 4                2004  2004-01-01T00:00:00+01:00  2004-12-31T00:00:00+01:00
#
# [5 rows x 25 columns]

# %%
df
# Out:
#           Id  IndicatorCode SpatialDimType SpatialDim ParentLocationCode  \
# 0    4005777  SA_0000001444        COUNTRY        EST                EUR
# 1       5547  SA_0000001444        COUNTRY        IND               SEAR
# 2    2081574  SA_0000001444        COUNTRY        FJI                WPR
# 3     465140  SA_0000001444        COUNTRY        MUS                AFR
# 4    3169152  SA_0000001444        COUNTRY        CZE                EUR
# ..       ...            ...            ...        ...                ...
# 568    32364  SA_0000001444        COUNTRY        TUR                EUR
# 569   410936  SA_0000001444        COUNTRY        DJI                EMR
# 570  9171368  SA_0000001444        COUNTRY        LKA               SEAR
# 571  4796140  SA_0000001444        COUNTRY        ATG                AMR
# 572  4181150  SA_0000001444        COUNTRY        WSM                WPR
#
#     TimeDimType         ParentLocation Dim1Type  TimeDim      Dim1  ...  \
# 0          YEAR                 Europe      SEX     2004   SEX_MLE  ...
# 1          YEAR        South-East Asia      SEX     2004   SEX_MLE  ...
# 2          YEAR        Western Pacific      SEX     2004  SEX_FMLE  ...
# 3          YEAR                 Africa      SEX     2004  SEX_BTSX  ...
# 4          YEAR                 Europe      SEX     2004  SEX_BTSX  ...
# ..          ...                    ...      ...      ...       ...  ...
# 568        YEAR                 Europe      SEX     2004  SEX_FMLE  ...
# 569        YEAR  Eastern Mediterranean      SEX     2004  SEX_FMLE  ...
# 570        YEAR        South-East Asia      SEX     2004  SEX_FMLE  ...
# 571        YEAR               Americas      SEX     2004  SEX_FMLE  ...
# 572        YEAR        Western Pacific      SEX     2004  SEX_FMLE  ...
#
#     DataSourceDim  Value NumericValue   Low  High Comments  \
# 0            None  326.7        326.7  None  None     None
# 1            None  239.3        239.3  None  None     None
# 2            None   71.9         71.9  None  None     None
# 3            None  225.1        225.1  None  None     None
# 4            None  148.0        148.0  None  None     None
# ..            ...    ...          ...   ...   ...      ...
# 568          None  176.5        176.5  None  None     None
# 569          None  214.0        214.0  None  None     None
# 570          None   75.6         75.6  None  None     None
# 571          None   59.6         59.6  None  None     None
# 572          None   71.3         71.3  None  None     None
#
#                           Date  TimeDimensionValue         TimeDimensionBegin  \
# 0    2013-06-11T14:15:34+02:00                2004  2004-01-01T00:00:00+01:00
# 1    2013-06-11T14:15:34+02:00                2004  2004-01-01T00:00:00+01:00
# 2    2013-06-11T14:15:34+02:00                2004  2004-01-01T00:00:00+01:00
# 3    2013-06-11T14:15:34+02:00                2004  2004-01-01T00:00:00+01:00
# 4    2013-06-11T14:15:34+02:00                2004  2004-01-01T00:00:00+01:00
# ..                         ...                 ...                        ...
# 568  2013-06-11T14:15:34+02:00                2004  2004-01-01T00:00:00+01:00
# 569  2013-06-11T14:15:34+02:00                2004  2004-01-01T00:00:00+01:00
# 570  2013-06-11T14:15:34+02:00                2004  2004-01-01T00:00:00+01:00
# 571  2013-06-11T14:15:34+02:00                2004  2004-01-01T00:00:00+01:00
# 572  2013-06-11T14:15:34+02:00                2004  2004-01-01T00:00:00+01:00
#
#               TimeDimensionEnd
# 0    2004-12-31T00:00:00+01:00
# 1    2004-12-31T00:00:00+01:00
# 2    2004-12-31T00:00:00+01:00
# 3    2004-12-31T00:00:00+01:00
# 4    2004-12-31T00:00:00+01:00
# ..                         ...
# 568  2004-12-31T00:00:00+01:00
# 569  2004-12-31T00:00:00+01:00
# 570  2004-12-31T00:00:00+01:00
# 571  2004-12-31T00:00:00+01:00
# 572  2004-12-31T00:00:00+01:00
#
# [573 rows x 25 columns]

# %%
df.loc["SpatialDim"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 df.loc["SpatialDim"]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1153, in _LocationIndexer.__getitem__(self, key)
#    1150 axis = self.axis or 0
#    1152 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1153 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1393, in _LocIndexer._getitem_axis(self, key, axis)
#    1391 # fall thru to straight lookup
#    1392 self._validate_key(key, axis)
# -> 1393 return self._get_label(key, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1343, in _LocIndexer._get_label(self, label, axis)
#    1341 def _get_label(self, label, axis: AxisInt):
#    1342     # GH#5567 this will fail if the label is not present in the axis.
# -> 1343     return self.obj.xs(label, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4236, in NDFrame.xs(self, key, axis, level, drop_level)
#    4234             new_index = index[loc]
#    4235 else:
# -> 4236     loc = index.get_loc(key)
#    4238     if isinstance(loc, np.ndarray):
#    4239         if loc.dtype == np.bool_:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\range.py:418, in RangeIndex.get_loc(self, key)
#     416         raise KeyError(key) from err
#     417 if isinstance(key, Hashable):
# --> 418     raise KeyError(key)
#     419 self._check_indexing_error(key)
#     420 raise KeyError(key)
#
# KeyError: 'SpatialDim'

# %%
# Save the data to a CSV file for further analysis
output_file = f"{indicator_code}_data.csv"
df.to_csv(output_file, index=False)
print(f"Data saved to {output_file}")
